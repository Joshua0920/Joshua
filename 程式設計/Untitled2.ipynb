# %%
number1= float(input("請輸入第一個數字："))
a=input("請輸入運算符號：")
number2=float(input("請輸入第二個數字"))
if a=="+":
  print(number1+number2)
elif a=="-":
  print(number1-number2)
elif a=="*":
  print(number1*number2)
elif a=="/":
  print(number1/number2)
else:
  print('無法計算')
# Out:
# 請輸入第一個數字：15
# 請輸入運算符號：/
# 請輸入第二個數字5
# 3.0

# %%
a=(input('輸入一串數字: ')).split()
for i in range(0,5):
  a[i]=int(a[i])
a=sorted(a)
del a[0]
del a[3]
print((a[0]+a[1]+a[2])/3)
# Out:
# 輸入一串數字: 10 20 40 50 70
# 36.666666666666664

# %%
[ ]
a=float(input("請輸入年份： "))
if  a > 1852:
  if   a%4==0:
    if   a%100==0:
      if   a%400==0:
               print('閏年')
      else:
                print('平年')
    else:
            print('閏年')
  else:
        print('平年')
else:
    if a%4==0:
       print('閏年')
    else:
      print('平年')
# Out:
# 請輸入年份： 2023
# 平年
